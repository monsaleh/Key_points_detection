# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

df_test = pd.read_csv('Data/testing.csv')
df_test.shape
# Out:
# (1783, 2)

# %%
def format_img(x):
    return np.asarray([int(e) for e in x.split(' ')], dtype=np.uint8)

# %%
X_test= np.stack([format_img(string) for string in df_test['Image']]).astype(np.float32)

# %%
def test_img(img_num):
    return np.reshape(X_test[img_num], (1,96,96,1))/255

# %%
def plot_sample(x, y):
    img = x.reshape(96, 96)
    plt.imshow(img, cmap='gray')
    plt.scatter(y[0::2] * 96, y[1::2] * 96, marker='o', s=10)

# %% [markdown]
# ***First Model***

# %%
from keras.models import load_model
model5 = load_model('model5.h5')

# %%
model5.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_5 (Batch (None, 96, 96, 1)         4
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 94, 94, 32)        320
# _________________________________________________________________
# activation_5 (Activation)    (None, 94, 94, 32)        0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 47, 47, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 46, 46, 64)        8256
# _________________________________________________________________
# activation_6 (Activation)    (None, 46, 46, 64)        0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 23, 23, 64)        0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 23, 23, 64)        256
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 23, 23, 64)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 22, 22, 128)       32896
# _________________________________________________________________
# activation_7 (Activation)    (None, 22, 22, 128)       0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 11, 11, 128)       0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 11, 11, 128)       512
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 10, 10, 256)       131328
# _________________________________________________________________
# activation_8 (Activation)    (None, 10, 10, 256)       0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 5, 5, 256)         0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 5, 5, 256)         1024
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 5, 5, 256)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 6400)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 500)               3200500
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               128256
# _________________________________________________________________
# dense_6 (Dense)              (None, 30)                7710
# =================================================================
# Total params: 3,511,062
# Trainable params: 3,510,164
# Non-trainable params: 898
# _________________________________________________________________

# %%
output = model5.predict(test_img(1))[0]
plot_sample(X_test[1], output)
plt.show()

output = model5.predict(test_img(4))[0]
plot_sample(X_test[4], output)
plt.show()

output = model5.predict(test_img(8))[0]
plot_sample(X_test[8], output)
plt.show()

output = model5.predict(test_img(10))[0]
plot_sample(X_test[10], output)
plt.show()

output = model5.predict(test_img(12))[0]
plot_sample(X_test[12], output)
plt.show()

output = model5.predict(test_img(16))[0]
plot_sample(X_test[16], output)
plt.show()

output = model5.predict(test_img(123))[0]
plot_sample(X_test[123], output)
plt.show()

output = model5.predict(test_img(6))[0]
plot_sample(X_test[6], output)
plt.show()

# %% [markdown]
# ***Second Model***

# %%
from keras.models import load_model
model5 = load_model('model458.h5')

# %%
model5.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_13 (Batc (None, 96, 96, 1)         4
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 94, 94, 24)        240
# _________________________________________________________________
# activation_13 (Activation)   (None, 94, 94, 24)        0
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 47, 47, 24)        0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 47, 47, 24)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 46, 46, 36)        3492
# _________________________________________________________________
# activation_14 (Activation)   (None, 46, 46, 36)        0
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 23, 23, 36)        0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 23, 23, 36)        144
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 23, 23, 36)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 22, 22, 48)        6960
# _________________________________________________________________
# activation_15 (Activation)   (None, 22, 22, 48)        0
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 11, 11, 48)        0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 11, 11, 48)        192
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 11, 11, 48)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 10, 10, 64)        12352
# _________________________________________________________________
# activation_16 (Activation)   (None, 10, 10, 64)        0
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 5, 5, 64)          0
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 5, 5, 64)          256
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 500)               800500
# _________________________________________________________________
# dense_11 (Dense)             (None, 500)               250500
# _________________________________________________________________
# dense_12 (Dense)             (None, 30)                15030
# =================================================================
# Total params: 1,089,670
# Trainable params: 1,089,372
# Non-trainable params: 298
# _________________________________________________________________

# %%
output = model5.predict(test_img(1))[0]
plot_sample(X_test[1], output)
plt.show()

output = model5.predict(test_img(4))[0]
plot_sample(X_test[4], output)
plt.show()

output = model5.predict(test_img(8))[0]
plot_sample(X_test[8], output)
plt.show()

output = model5.predict(test_img(10))[0]
plot_sample(X_test[10], output)
plt.show()

output = model5.predict(test_img(12))[0]
plot_sample(X_test[12], output)
plt.show()

output = model5.predict(test_img(16))[0]
plot_sample(X_test[16], output)
plt.show()

output = model5.predict(test_img(123))[0]
plot_sample(X_test[123], output)
plt.show()

output = model5.predict(test_img(6))[0]
plot_sample(X_test[6], output)
plt.show()

# %% [markdown]
# ***Third Model***

# %%
from keras.models import load_model
model5 = load_model('modelwetg5.h5')

# %%
model5.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_17 (Batc (None, 96, 96, 1)         4
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 94, 94, 24)        240
# _________________________________________________________________
# activation_17 (Activation)   (None, 94, 94, 24)        0
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 47, 47, 24)        0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 46, 46, 36)        3492
# _________________________________________________________________
# activation_18 (Activation)   (None, 46, 46, 36)        0
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 23, 23, 36)        0
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 23, 23, 36)        144
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 23, 23, 36)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 22, 22, 48)        6960
# _________________________________________________________________
# activation_19 (Activation)   (None, 22, 22, 48)        0
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 11, 11, 48)        0
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 11, 11, 48)        192
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 10, 10, 64)        12352
# _________________________________________________________________
# activation_20 (Activation)   (None, 10, 10, 64)        0
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 5, 5, 64)          0
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 5, 5, 64)          256
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 500)               800500
# _________________________________________________________________
# dense_14 (Dense)             (None, 500)               250500
# _________________________________________________________________
# dense_15 (Dense)             (None, 30)                15030
# =================================================================
# Total params: 1,089,670
# Trainable params: 1,089,372
# Non-trainable params: 298
# _________________________________________________________________

# %%
output = model5.predict(test_img(1))[0]
plot_sample(X_test[1], output)
plt.show()

output = model5.predict(test_img(4))[0]
plot_sample(X_test[4], output)
plt.show()

output = model5.predict(test_img(8))[0]
plot_sample(X_test[8], output)
plt.show()

output = model5.predict(test_img(10))[0]
plot_sample(X_test[10], output)
plt.show()

output = model5.predict(test_img(12))[0]
plot_sample(X_test[12], output)
plt.show()

output = model5.predict(test_img(16))[0]
plot_sample(X_test[16], output)
plt.show()

output = model5.predict(test_img(123))[0]
plot_sample(X_test[123], output)
plt.show()

output = model5.predict(test_img(6))[0]
plot_sample(X_test[6], output)
plt.show()
